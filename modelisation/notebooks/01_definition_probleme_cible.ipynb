# %% [markdown]
# # Définition du problème et de la cible
#
# Le SOCLE prédit un défaut à 30 jours. `date_deblocage` est le proxy documenté de la date de demande ; les classes 15–29 jours et non matures sont exclues de l'entraînement.

# %%
from pathlib import Path
import pandas as pd

jeu = pd.read_parquet(Path.cwd() / 'data/processed/jeu_socle.parquet')
jeu[['classe_cible', 'cible', 'split']].value_counts().sort_index()
