# %% [markdown]
# # Référence logistique
#
# La référence partage dataset et plis temporels avec EBM. Ses transformations (imputation, indicateurs, one-hot, standardisation) restent internes à sa pipeline et n'altèrent jamais le Parquet SOCLE.

# %%
from pathlib import Path
import json

rapport = Path.cwd() / 'data/modeles/reference_test.json'
assert rapport.exists(), 'Exécuter la commande d entraînement avant ce notebook.'
json.loads(rapport.read_text())
