# %% [markdown]
# # Analyse multivariée et redondance
#
# La corrélation sert au diagnostic ; aucune feature SOCLE n'est retirée automatiquement sans décision métier.

# %%
from pathlib import Path
import pandas as pd
from solida_modelisation.catalogue import FEATURES_SOCLE

jeu = pd.read_parquet(Path.cwd() / 'data/processed/jeu_socle.parquet')
numeriques = [f.code for f in FEATURES_SOCLE if f.type_ebm == 'continue']
jeu[numeriques].corr(numeric_only=True).round(2)
