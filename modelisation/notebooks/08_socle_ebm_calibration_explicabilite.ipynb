# %% [markdown]
# # SOCLE EBM : calibration et explicabilité
#
# EBM reçoit les types explicites, les manquants séparés et les catégories natives. Il n'y a ni dummies, ni mise à l'échelle, ni imputation manuelle.

# %%
from pathlib import Path
import json
from solida_modelisation.inference import ModeleSocle

dossier = Path.cwd() / 'data/modeles/bundle_socle'
modele = ModeleSocle.depuis_dossier(dossier)
metriques = json.loads((Path.cwd() / 'data/modeles/socle_test.json').read_text())[0]
{'version': modele.version, 'checksum': modele.checksum, **metriques}
